# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.8/dist-packages (3.3.1)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.8/dist-packages (from pyspark) (0.10.9.5)

# %%
import pyspark
import pandas as pd
from pyspark.sql.functions import split, explode, col, lower, sort_array
import pyspark.sql.functions as F
from google.colab import drive
drive.mount('/content/drive')
import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/parking2017.csv') #read the csv by panad

# %%
pd.set_option("display.max_rows", None) #to see all the value counts

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Streaming output truncated to the last 5000 lines.
# East End Ave              210
# E 174th St                210
# 114th St                  210
# Guernsey St               210
# College Ave               209
# W 93rd St                 209
# Bainbridge St             209
# Watson Ave                208
# Midwood St                208
# Old Slip                  208
# Wilson Ave                208
# 46th Rd                   208
# 30th Rd                   207
# Argyle Rd                 207
# Fenimore St               207
# Hooper St                 207
# Burling St                206
# N 11th St                 206
# Dupont St                 206
# Intervale Ave             206
# Suffolk St                205
# 169th St                  205
# Fox St                    205
# W 136th St                205
# 117th St                  205
# Van Wyck Expy             204
# W 134th St                204
# Manor Ave                 203
# W 95th St                 203
# Castleton Ave             202
# Pleasant Ave              202
# Kingsland Ave             201
# Harrison Ave              201
# Milton St                 201
# 106th St                  201
# Cadman Plaza West         199
# Ross St                   198
# Berkeley Pl               198
# E 210th St                198
# E 161st St                198
# Caton Ave                 198
# Independence Ave          197
# Plaza Street East         197
# 39th Pl                   197
# Beach Ave                 197
# Maple St                  197
# 16th St                   196
# W 94th St                 196
# E 181st St                196
# 147th Pl                  196
# Bay 19th St               196
# E 163rd St                196
# Pierrepont St             195
# Rochester Ave             195
# Woodward Ave              194
# Hamilton Pl               194
# Netherland Ave            194
# 69th Pl                   193
# Andrews Ave               193
# 62nd Dr                   193
# Middleton St              193
# Gravesend Neck Rd         193
# 60th Ln                   193
# 76th Ave                  192
# E 164th St                192
# Hillel Pl                 192
# Mount Eden Ave            192
# 87th Ave                  192
# W 150th St                192
# Glenmore Ave              191
# 121st St                  190
# Montrose Ave              189
# Shore Blvd                189
# Bradhurst Ave             188
# E 127th St                188
# 58th Ave                  188
# 136th St                  188
# Cherry Ave                188
# Hutchinson River Pky      188
# 69th Rd                   187
# Cabrini Blvd              187
# Frisby Ave                187
# Longfellow Ave            187
# Lynch St                  186
# W 110th St                186
# McKibbin St               186
# Dreiser Loop              186
# South St                  186
# Devoe St                  186
# E 124th St                186
# Duffield St               185
# Stratford Rd              185
# W 107th St                185
# Wayne Ave                 185
# 17th St                   184
# Aqueduct Ave              184
# W 109th St                184
# Ponton Ave                184
# Norman St                 183
# Clark St                  183
# E 152nd St                183
# Center Blvd               183
# Maran Pl                  183
# 115th St                  183
# Summerfield St            182
# Columbia St               182
# Eastchester Rd            182
# Haven Ave                 182
# Bryant Ave                182
# Wheeler Ave               181
# Monitor St                181
# Van Sicklen St            181
# Stuyvesant Ave            180
# W 147th St                180
# Skillman St               180
# Garfield Pl               180
# Wythe Pl                  180
# Diamond St                179
# W 153rd St                178
# Wyckoff St                178
# Cook St                   178
# 2nd Pl                    178
# St James Pl               178
# 124th St                  177
# 20th St                   177
# Wexford Ter               176
# Maujer St                 176
# W 140th St                175
# Vestry St                 175
# Carpenter Ave             175
# 149th Pl                  175
# Schaefer St               175
# Linwood St                174
# Keap St                   174
# Horatio St                173
# W 133rd St                173
# Leroy St                  172
# W 190th St                172
# Wortman Ave               172
# W 151st St                171
# Clarendon Rd              171
# Butler St                 170
# W 185th St                170
# Pitt St                   170
# Rockwell Pl               170
# 85th Ave                  170
# Fulton Ave                169
# N 3rd St                  169
# 62nd Ave                  169
# Central Park South        169
# Pennsylvania Ave          169
# Douglaston Pky            169
# 68th Dr                   168
# Bronx River Ave           168
# S 9th St                  168
# Tilden Ave                168
# Saratoga Ave              167
# Starling Ave              167
# W Mosholu Pky             167
# Cross Bronx Expy          167
# W Houston St              167
# E 153rd St                166
# Briggs Ave                166
# Mac Dougal St             166
# Calyer St                 166
# N 5th St                  166
# 107th St                  165
# 179th St                  165
# E 103rd St                165
# E 211th St                165
# Bergen Ave                165
# W 132nd St                165
# S William St              165
# Hobart Ave                165
# E 148th St                164
# 45th Rd                   164
# Dumont Ave                164
# Brighton 4th St           164
# 111th St                  163
# Edison Ave                163
# E 186th St                163
# Mount Eden Pky            163
# 75th Rd                   163
# W 163rd St                163
# W 138th St                162
# Crotona Park              162
# 180th St                  162
# Ridge Blvd                162
# Paul Ave                  162
# S Elliott Pl              161
# Corlear Ave               161
# Hone Ave                  161
# Noble St                  160
# Cloverdale Blvd           160
# 26th St                   160
# Leavitt St                160
# Lorillard Pl              160
# Cumberland St             159
# Chestnut St               159
# Eldert St                 159
# Fort Greene Pl            159
# Sheffield Ave             158
# St Anns Ave               158
# S 6th St                  158
# Brighton 13th St          157
# Fairview Ave              157
# Whitehall St              156
# 143rd St                  156
# Avenue R                  156
# 67th Dr                   156
# W 61st St                 156
# Kenmare St                156
# E 225th St                155
# Renwick St                155
# Gramercy Park West        154
# Adams St                  154
# 59th Ave                  154
# Olmstead Ave              153
# Wood Rd                   153
# Newel St                  152
# Barrow St                 152
# Blake Ave                 152
# W 176th St                151
# Stagg St                  151
# Farmers Blvd              151
# Hicks St                  150
# 79th Ave                  150
# Macdougal St              150
# Waltham St                150
# Guerlain St               150
# Jennings St               150
# 109th St                  149
# S Oxford St               149
# De Kalb Ave               149
# Ten Eyck St               149
# Elliot Pl                 149
# 77th Rd                   149
# E Broadway.               148
# Gleane St                 148
# 170th St                  148
# Gansevoort St             147
# 84th Ave                  147
# W 102nd St                146
# Russell St                146
# Paulding Ave              146
# Benedict Ave              146
# Canal Pl                  146
# Sumpter St                145
# W 186th St                145
# Fort George Hill          145
# Rosedale Ave              144
# Melrose St                144
# 123rd St                  144
# Hugh J Grant Cir          144
# Forest Pky                143
# W 80th St                 143
# Richardson St             143
# 175th St                  143
# E 182nd St                143
# Elbertson St              143
# Cauldwell Ave             143
# Marion St                 143
# Malcolm X Blvd            143
# 137th St                  142
# W 204th St                142
# Stockton St               141
# Britton Ave               141
# Vyse Ave                  141
# E 139th St                141
# 86th Ave                  141
# Clarkson St               140
# Astor Ave                 140
# Benson Ave                140
# Withers St                140
# W 175th St                139
# Cambreleng Ave            139
# Purdy St                  139
# Station Rd                139
# Ryer Ave                  139
# Lake St                   139
# Pike St                   138
# Van Nest Ave              138
# Brighton 5th St           138
# Brighton 3rd St           138
# 171st St                  138
# 122nd St                  138
# W 187th St                138
# 63rd Ave                  137
# Clymer St                 137
# Harlem River Dr           137
# Hoover Ave                137
# Charles St                137
# W 172nd St                137
# Bradford St               136
# N Moore St                136
# Ithaca St                 135
# Downing St                135
# E 205th St                135
# Findlay Ave               135
# Brighton 11th St          135
# Jane St                   134
# Beck St                   134
# Whipple St                134
# W 128th St                134
# 31st Dr                   134
# Gramercy Park South       133
# Monterey Ave              133
# W 141st St                133
# 65th Pl                   133
# E 176th St                133
# Colonel Robert Magaw      132
# 72nd Dr                   132
# St Lawrence Ave           132
# 29th Ave                  132
# E 198th St                132
# Empire Blvd               132
# Radcliff Ave              131
# W 152nd St                131
# Ridge St                  131
# Sutter Ave                131
# 131st St                  131
# Gerry St                  131
# Avenue W                  131
# 31st Rd                   130
# Colgate Ave               130
# Bennett Ave               130
# Barbey St                 130
# Brighton 2nd St           130
# Hall of Fame Ter          130
# Anthony Ave               129
# Covert St                 129
# W 177th St                129
# Williams Ave              129
# Wilson St                 129
# 53rd Ave                  128
# 168th St                  128
# Carmine St                128
# 54th Ave                  128
# Thomas S Boyland St       128
# Van Buren St              128
# W 155th St                127
# Gerard Pl                 127
# Frost St                  127
# Dalny Rd                  126
# E 108th St                126
# W 148th St                126
# W 137th St                126
# Willis Ave                125
# Meserole Ave              125
# Cleveland St              125
# Commonwealth Ave          125
# Rodney St                 125
# Seaman Ave                125
# Hope St                   125
# 14th Rd                   125
# Corbin Pl                 124
# Concord Ave               124
# Mace Ave                  124
# Plaza Pl                  124
# St Paul Pl                124
# Post Ave                  124
# Morgan Ave                123
# Lincoln Ave               123
# Blondell Ave              123
# Jerome St                 122
# Colden Ave                122
# 12th Rd                   122
# 60th Ave                  122
# Mott Ave                  122
# Manhattan College Pk      122
# Hoyt Ave South            122
# W 1st St                  121
# Hylan Blvd                121
# E 226th St                121
# F D R Dr                  121
# Washington Park           121
# Moffat St                 121
# Morris St                 121
# Ashford St                120
# Cedar Ave                 120
# N 1st St                  120
# Logan St                  120
# W 131st St                120
# 176th St                  119
# E 224th St                119
# Schenck Ave               119
# Noble Ave                 119
# Hanson Pl                 119
# 126th St                  118
# 178th St                  118
# Grandview Ave             118
# W 232nd St                117
# Webb Ave                  117
# Desbrosses St             117
# Division St               117
# Oceanview Ave             117
# Rev James A Polite A      117
# E 229th St                116
# E 213th St                116
# Tiffany St                116
# Plymouth St               116
# 78th Rd                   116
# Cozine Ave                116
# Livonia Ave               115
# Kossuth Ave               115
# Brighton 1st St           115
# Bay Ave                   115
# Van Cortlandt Ave         115
# 57th Rd                   114
# Rutgers St                114
# Hanover Pl                113
# 135th St                  113
# W 173rd St                113
# Hendrix St                113
# Gouverneur St             113
# E 144th St                112
# Lincoln Rd                112
# Douglass St               112
# Gleason Ave               112
# Box St                    111
# Sutton St                 111
# Pearson St                110
# Hegeman Ave               110
# Other-See Comments        110
# Dorchester Rd             110
# Walton St                 110
# Rhinelander Ave           110
# Beech Ave                 109
# E 206th St                109
# 92nd Rd                   109
# Louisiana Ave             109
# Story Ave                 109
# Vandam St                 108
# 218th St                  108
# W 174th St                108
# Bush St                   108
# Barker Ave                107
# Hawthorne St              107
# Grand Central Pky         107
# Roberts Ave               107
# 217th St                  107
# Gramercy Park             107
# Gramercy Park East        107
# Emerson Pl                106
# E 168th St                106
# Hoe Ave                   106
# 49th Ave                  106
# Barnett Ave               106
# Elton St                  106
# Beach St                  105
# Freedom Pl                105
# E 141st St                105
# Co Op City Blvd           105
# Watts St                  105
# Shepherd Ave              105
# Arnow Ave                 104
# Exchange Pl               104
# Arlington Ave             104
# E 147th St                104
# 155th St                  104
# Loring Pl                 104
# Colonial Rd               103
# Mother Gaston Blvd        103
# Waldo Ave                 103
# E 143rd St                102
# E 130th St                102
# 85th Dr                   102
# 78th Cres                 102
# New Dorp Plz South        102
# 97th Pl                   102
# Crocheron Ave             101
# W 168th St                101
# Hubert St                 101
# Vesey St                  101
# 27th Ave                  101
# Seagirt Blvd              101
# 52nd Ave                  101
# Trinity Ave               101
# Vermilyea Ave             100
# E 232nd St                100
# Reservoir Oval            100
# Reservoir Ave             100
# W 162nd St                100
# 173rd St                  100
# Kelly St                  100
# Patchen Ave               100
# Snediker Ave              100
# Beverly Rd                100
# Atkins Ave                100
# Waring Ave                 99
# Maspeth Ave                99
# Baisley Blvd               99
# Magenta St                 99
# Greystone Ave              98
# Mapes Ave                  98
# E 222nd St                 98
# E 220th St                 98
# E 146th St                 98
# W 234th St                 97
# 33rd Rd                    97
# Lefferts Pl                97
# Bay 25th St                97
# W 103rd St                 97
# Pelham  Pkwy North         97
# Montauk Ave                96
# 188th St                   96
# Surrey Pl                  96
# Grenfell St                96
# Market St                  96
# Van Cortlandt Park         96
# E 140th St                 95
# Clay St                    95
# E 199th St                 95
# Park Ln South              95
# Woodycrest Ave             95
# Forbell St                 95
# Times Sq                   95
# Beach 19th St              94
# Remsen Ave                 94
# Inwood Ave                 94
# 84th Rd                    94
# 81st Ave                   94
# Hunter St                  94
# Selwyn Ave                 94
# E 175th St                 94
# Old Broadway               93
# E 142nd St                 93
# Amity St                   93
# E 121st St                 93
# 87th Rd                    93
# Grace Ct                   93
# Benson St                  93
# Montgomery Ave             93
# E 219th St                 93
# Pugsley Ave                93
# Winthrop Pl                92
# Pelham Pkway South         92
# Pelham Pkwy N              92
# Battery Pl                 92
# Blossom Ave                92
# Regent Pl                  92
# Locust Ave                 91
# Barretto St                91
# McGraw Ave                 91
# Dominick St                90
# Judge St                   90
# 97th Ave                   90
# Wanamaker Pl               90
# Bay 29th St                90
# E 216th St                 90
# W 195th St                 90
# Hinsdale St                90
# E 145th St                 90
# Utopia Pky                 90
# 142nd St                   89
# Fort Hamilton Pky          89
# Hopkins St                 89
# Queens Plaza South         89
# Kingsbridge Ter            89
# Wood Ave                   89
# Home St                    89
# E 228th St                 88
# Irwin Ave                  87
# W 242nd St                 87
# Cropsey Ave                87
# Centre Market Pl           87
# Thomson Ave                87
# Muliner Ave                87
# 69th Ln                    87
# Warwick St                 87
# Bogart Ave                 87
# W 154th St                 87
# York St                    87
# Fredrick Douglas Blv       87
# Brady Ave                  86
# 58th Rd                    86
# 3rd Pl                     86
# Hull St                    86
# Lurting Ave                86
# Ellis Ave                  86
# Autumn Ave                 86
# Garrison Ave               86
# Taylor St                  86
# 235th St                   86
# Pinehurst Ave              86
# Manida St                  85
# 150th Pl                   85
# 219th St                   84
# Coolidge Ave               84
# Cooper Ave                 84
# E 131st St                 84
# Bristol St                 84
# E 231st St                 83
# Archer St                  83
# Kimberly Pl                83
# Faile St                   83
# Hall St                    83
# E 169th St                 82
# 130th St                   82
# Williamsburg St West       82
# Bedford St                 82
# Thames St                  82
# Brighton 12th St           82
# 86th Rd                    82
# Cambridge Pl               81
# Croes Ave                  81
# Harrod Ave                 81
# W 139th St                 81
# W 2nd St                   81
# Adee Ave                   81
# Richmond Ave               81
# Oxford St                  81
# W 101st St                 81
# Mount Hope Pl              81
# Rider Ave                  80
# 60th Pl                    80
# Hemlock St                 80
# W 161st St                 80
# Village Rd N               80
# Lyon Ave                   79
# W 66th St                  79
# Powell Ave                 79
# E 154th St                 79
# Senator St                 79
# Perry St                   79
# Macombs Rd                 79
# 20th Rd                    78
# 152nd St                   78
# Nelson Ave                 78
# Milford St                 78
# E 241st St                 78
# Laburnum Ave               77
# E 134th St                 77
# Glebe Ave                  77
# Adam C Powell Blvd         77
# Kappock St                 76
# Laconia Ave                76
# Amboy St                   76
# Havemeyer Ave              76
# Alabama Ave                75
# Exeter St                  75
# E 137th St                 75
# 137th Ave                  75
# Robinson St                75
# 90th Rd                    75
# E 193rd St                 74
# Cuthbert Rd                74
# Brighton 14th St           74
# Marine Ave                 74
# Astoria Pk South           74
# Williamsburg St East       74
# Georgia Ave                74
# W 237th St                 74
# Bay 23rd St                73
# Dawson St                  73
# Congress St                73
# New Haven Ave              73
# 156th St                   73
# St Felix St                73
# Lafontaine Ave             73
# 86th Dr                    73
# E 196th St                 72
# W 192nd St                 72
# Doscher St                 72
# W 205th St                 72
# E 223rd St                 72
# Gallatin Pl                72
# Fowler Ave                 72
# Fort Independence St       72
# Seymour Ave                72
# Louis Nine Blvd            72
# Boone Ave                  72
# W 99th St                  72
# Metcalf Ave                72
# E 217th St                 71
# 177th St                   71
# Traffic Ave                71
# Vleigh Pl                  71
# Narrows Ave                71
# Bay 32nd St                71
# Grace Ave                  71
# Park Dr                    71
# Henley Rd                  71
# 93rd Ave                   71
# Engert Ave                 70
# E 135th St                 70
# Bay 31st St                70
# W 215th St                 70
# Berriman St                70
# Duryea Pl                  70
# Edgerton Blvd              70
# Pembroke St                70
# Hunt Ave                   70
# 156th Ave                  70
# Haviland  Ave              70
# Woodruff Ave               70
# Blackrock Ave              70
# Cromwell Ave               69
# 161st Ave                  69
# Forley St                  69
# Van Dam St                 69
# Ryerson St                 69
# Schley Ave                 69
# Eliot Ave                  69
# E 221st St                 69
# Nichols Ave                69
# E 132nd St                 69
# 28th Rd                    69
# Lott Pl                    69
# E 136th St                 69
# Paladino Ave               69
# Willets Point Blvd         69
# Woodpoint Rd               69
# Avenue F                   68
# Freeport Loop              68
# Steuben St                 68
# Chester St                 68
# Windsor Pl                 68
# 132nd St                   68
# Laurel Hill Blvd           68
# Ash Ave                    68
# Fteley Ave                 68
# Desmond Ct                 67
# Hamilton Ave               67
# Fenton Ave                 67
# Exterior St                67
# W 240th St                 67
# New Lots Ave               67
# W 100th St                 67
# Tenbroeck Ave              67
# E 212th St                 67
# Hillman Ave                67
# Bedell St                  67
# Putnam Pl                  67
# Katonah Ave                67
# 110th Ave                  67
# Tuskegee Airman Way        67
# Smart St                   66
# Banker St                  66
# Jarvis Ave                 66
# 125th St                   66
# Haight St                  66
# Baughman Pl                66
# E 150th St                 66
# Jericho Tpke               66
# Elton Ave                  66
# W 159th St                 66
# Crotona Pky                66
# Brooklyn Queens Expy       66
# 144th St                   65
# Corsa Ave                  65
# 167th St                   65
# St Nicholas Pl             65
# Dyre Ave                   65
# Brighton 1st Pl            65
# McKibben St                65
# Hazen St                   65
# N 14th St                  64
# Tudor City Pl              64
# Amersfort Pl               64
# W 166th St                 64
# Fink Ave                   64
# Monument Walk              64
# Clifford Pl                64
# Saull St                   64
# Mac Kenzie St              64
# Crooke Ave                 64
# Kingsbridge Ave            64
# 67th Pl                    64
# 62nd Rd                    64
# 182nd St                   63
# 157th St                   63
# Slosson Ter                63
# Featherbed Ln              63
# Bay 35th St                63
# E 214th St                 63
# Lewis St                   63
# Kane St                    63
# Benham St                  63
# Pettit Ave                 63
# Almeda Ave                 63
# Stuyvesant St              63
# La Salle St                63
# Beaumont Ave               62
# W 65th St                  62
# Hunts Point Ave            62
# Alstyne Ave                62
# N Henry St                 62
# Bay 16th St                62
# W 239th St                 62
# Chestnut Ave               62
# Otto Rd                    61
# Orloff Ave                 61
# E 207th St                 61
# Prospect Park SW           61
# Bassford Ave               61
# Crystal St                 61
# Oriental Blvd              61
# Villa Ave                  61
# Albany St                  60
# Jewel St                   60
# Bay 20th St                60
# Monroe Ave                 60
# 184th St                   60
# Roder Ave                  60
# Parker St                  60
# Pershing Cres              60
# Clyde St                   60
# St Peters Ave              60
# Cornish Ave                60
# 23rd Rd                    59
# Bay 28th St                59
# 189th St                   59
# Platt St                   59
# E 230th St                 59
# 111st St                   59
# Einstein Loop              59
# Amherst St                 59
# Weeks Ave                  58
# Overlook Ter               58
# W Tremont Ave              58
# Bay 37th St                58
# E 162nd St                 58
# Academy St                 58
# Audley St                  58
# 154th St                   58
# Juniper Ave                58
# Somers St                  58
# Sullivan Pl                58
# 26th Ave                   58
# Montgomery Pl              57
# Simpson St                 57
# E 218th St                 57
# Buffalo Ave                57
# Isham St                   57
# Halperin Ave               57
# E 201st St                 57
# Brush Ave                  57
# Butler Pl                  57
# E Houston St.              56
# N Oxford St                56
# Bogart St                  56
# Heath Ave                  56
# Brightwater Ct             56
# Attorney St                56
# W 230th St                 55
# 80th Rd                    55
# Bud Pl                     55
# Junius St                  55
# Kew Forest Ln              54
# Mc Graw Ave                54
# Turnbull Ave               54
# Hendrickson St             54
# Case St                    54
# East Mount Eden Ave        53
# Avenue of the Americ       53
# N 13th St                  53
# Field Pl                   53
# W 211th St                 53
# Abingdon Rd                53
# Topping Ave                53
# Dongan Ave                 53
# Grassmere Ter              53
# Old Fulton St              53
# Avery Ave                  53
# Archer Ave                 52
# 66th Pl                    52
# Nelson St                  52
# Highland Blvd              52
# Virginia Ave               52
# Gateway Blvd               52
# E 227th St                 52
# N Portland Ave             52
# W 225th St                 52
# Bay 14th St                52
# Shore Front Pky            51
# Bayview Ave                51
# Benson Pl                  51
# Pelman Pkway south         51
# 187th St                   51
# Christie Ave               51
# E 107th St                 51
# Brighton 8th St            51
# Wales Ave                  51
# Hubbard St                 51
# Selfridge St               51
# 73rd Pl                    51
# Beach 54th St              50
# 133rd St                   50
# Warsoff Pl                 50
# Caffrey Ave                50
# Queens Plaza North         50
# Dartmouth St               50
# Bay 26th St                50
# Highlawn Ave               50
# Oliver St                  50
# S 10th St                  50
# Coleridge St               50
# E 177th St                 50
# Rector Pl                  50
# W 167th St                 50
# Chester Ave                50
# Delaware Ave               50
# Garland Dr                 50
# Dover St                   50
# Eagle Ave                  50
# Lott St                    50
# 144th Pl                   49
# Prospect St                49
# Main Ave                   49
# Cross Bronx Expy Svc       49
# Legion St                  49
# Jackson Mill Rd            49
# 179th Pl                   49
# Dunne Ct                   49
# Davis St                   49
# Olive St                   49
# Goodwin Pl                 49
# Alderton St                49
# Grand Central Pkwy S       49
# Village Rd S               49
# Boerum Pl                  49
# E 215th St                 49
# Bay 17th St                49
# Tonsor St                  49
# Hamilton Ter               48
# Odell St                   48
# Bartlett St                48
# Overing St                 48
# Otis Ave                   48
# Close Ave                  48
# Rockwood St                48
# Bolton Ave                 48
# Chapin Pky                 48
# Herbert St                 48
# Haring St                  48
# Gothic Dr                  48
# Drew St                    48
# Timpson Pl                 48
# Marmion Ave                48
# 184th Pl                   48
# Apollo St                  48
# Hale Ave                   47
# Wilkinson Ave              47
# Mc Clellan St              47
# Aberdeen St                47
# Hewitt Pl                  47
# Jewett Ave                 47
# Beach 51st St              47
# Fish Ave                   47
# Bristow St                 46
# Rogers Pl                  46
# Locust St                  46
# 181st St                   46
# Veronica Pl                46
# Verveelen Pl               46
# McKeever Pl                46
# Oak St                     46
# 166th St                   46
# Daniels St                 46
# E 197th St                 46
# Norwood Ave                46
# W 158th St                 46
# Ingraham St                45
# Dunham Pl                  45
# Shakespeare Ave            45
# Dexter Ct                  45
# Sandford St                45
# Baruch Dr                  45
# Denman St                  45
# Fieldston Rd               45
# Ketcham St                 45
# 140th St                   45
# Needham Ave                45
# 148th Ave                  45
# Beach 108th St             44
# St Theresa Ave             44
# Fleet St                   44
# Colonial Ave               44
# 85th Rd                    44
# Lowe Ct                    44
# Commercial St              44
# Harrison St                44
# Babbage St                 44
# Sickles St                 44
# Cass Pl                    43
# Lawrence Ave               43
# North St                   43
# Beach 102nd St             43
# Payson Ave                 43
# St Felix Ave               43
# 37th Dr                    43
# Maclay Ave                 43
# Sunnyside Ave              43
# Tryon Ave                  43
# Kings College Pl           43
# Kessel St                  43
# Clinton Pl                 43
# Willett Ave                43
# Dobbin St                  43
# Henry Hudson Pky           43
# South Rd                   43
# Bethune St                 42
# Vanderbilt St              42
# E 160th St                 42
# Brighton 15th St           42
# Marble Hill Ave            42
# McCllean Street            42
# Beaumont St                42
# Eltingville Blvd           42
# Bayside Ave                42
# 4th Pl                     42
# Herschell St               42
# Ericsson St                42
# Janet Pl                   41
# Macombs Pl                 41
# 145th St                   41
# W 206th St                 41
# Vandalia Ave               41
# Nicolls Ave                41
# Chatterton Ave             41
# Mowbray Dr                 41
# E 234th St                 41
# Talbot St                  41
# Granite St                 41
# De Sales Pl                41
# Balcom Ave                 41
# Geneva Loop                40
# Edward L Grant Hwy         40
# Seabury St                 40
# Whitestone Expy Svc        40
# Beach 21st St              40
# Folin St                   40
# Paerdegat Ave N            40
# Donizetti Pl               40
# Beach 57th St              40
# Monroe Pl                  40
# Mansion St                 40
# E 122nd St                 40
# W 98th St                  40
# E 129th St                 40
# Hanover St                 39
# Gouverneur Ave             39
# W 218th St                 39
# Longwood Ave               39
# Lander St                  39
# Whitlock Ave               39
# N Railroad Ave             39
# Parkside Pl                39
# Layton St                  39
# Bouck Ave                  39
# Schieffelin Ave            39
# Parade Pl                  39
# 129th St                   38
# Pilling St                 38
# 55th Dr                    38
# Lacombe Ave                38
# 185th St                   38
# 243rd St                   38
# Bay 34th St                38
# Rose Ave                   38
# Szold Pl                   38
# Westcott Blvd              38
# Bellamy Loop               38
# Washington Sq              38
# Dahlia Ave                 38
# Concourse Village E        38
# Cliff St                   38
# Strauss St                 37
# Eastburn Ave               37
# Hampton Ave                37
# Peck Ave                   37
# Arion Pl                   37
# Minna St                   37
# Oak Point Ave              37
# Vanhorn St                 37
# Enfield Pl                 37
# Alexander Ave              37
# 25th St                    37
# Seward Ave                 37
# S Oak Dr                   37
# 158th Ave                  37
# Little Nassau St           37
# W 203rd St                 37
# 212th St                   37
# Garden St                  37
# Center St                  37
# Little Neck Pky            37
# Hawthorne Ave              36
# Kenilworth Dr              36
# 127th St                   36
# Grafton St                 36
# Fleet Pl                   36
# Arverne Blvd               36
# Holly Ave                  36
# Undercliff Ave             36
# Negundo Ave                36
# Strong Pl                  36
# Daly Ave                   36
# Hillyer St                 36
# 34th Rd                    36
# Orient Ave                 36
# Rombouts Ave               36
# Maurice Ave                36
# Hampton St                 36
# King Rd                    36
# Cooper St                  36
# 228th St                   36
# Seeley St                  35
# Honeywell Ave              35
# Harrison Pl                35
# Liverpool St               35
# Fuller Pl                  35
# 64th Pl                    35
# Huntington St              35
# W 196th St                 35
# W 157th St                 35
# Tiemann Pl                 35
# Schiefflin Pl              35
# 254th St                   35
# Queens Midtown Expy        35
# Hoxie Dr                   35
# Fresh Meadow Ln            35
# Yates Ave                  35
# Burden Cres                35
# Fairfield Ave              35
# Parkview Ter               35
# Continental Ave            35
# 98th Pl                    35
# Claflin Ave                35
# Groton St                  35
# St Pauls Ave               35
# 183rd St                   34
# Beaver Rd                  34
# Sterling St                34
# Barry St                   34
# W 189th St                 34
# Juniper Blvd               34
# Redding St                 34
# E 236th St                 34
# Loretta Rd                 34
# North Railroad Ave         34
# Ryder Ave                  34
# Givan Ave                  34
# Evelyn Pl                  34
# Oak Ave                    34
# Juno St                    34
# Bartholdi St               33
# Marcy Pl                   33
# Richmond Rd                33
# Albany Cres                33
# Cornaga Ave                33
# River Ave                  33
# Newport St                 33
# Tratman Ave                33
# Park St                    33
# Smedley St                 33
# Conklin Ave                33
# Herzl St                   33
# 21st Dr                    33
# Loring Ave                 33
# Tapscott St                33
# Carver Loop                33
# 186th St                   33
# Beach 97th St              33
# Ingram St                  33
# Review Ave                 33
# 68th Pl                    33
# Miles Ave                  32
# Oakland Pl                 32
# Amethyst St                32
# Kossuth Pl                 32
# Post Rd                    32
# Review Pl                  32
# 74th Ave                   32
# Thwaites Pl                32
# Jackie Robinson Pkwy       32
# Crawford Ave               32
# Gillmore St                32
# Columbia Heights           32
# Hausman St                 32
# Oakland Ave                32
# St Paul Ave                32
# Luquer St                  32
# 138th Pl                   32
# Peck Slip                  32
# E 159th St                 32
# Bay 43rd St                32
# Avenue Saint John          32
# Mount Morris Park          32
# Halleck St                 32
# St Francis Pl              32
# Richmond St                31
# Minford Pl                 31
# Jesup Ave                  31
# Beach 17th St              31
# Charlotte St               31
# Lebanon St                 31
# Fayette St                 31
# 134th Rd                   31
# E 157th St                 31
# Summit St                  31
# Clawson St                 31
# Chevy Chase St             31
# 109th Ave                  31
# 193rd St                   31
# Knox Pl                    31
# Neill Ave                  31
# Poplar St                  31
# Newton St                  31
# Ritter Pl                  30
# Etna St                    30
# Navy St                    30
# Harrow St                  30
# Mermaid Ave                30
# Bay 22nd St                30
# Hornell Loop               30
# Home Lawn St               30
# Paerdegat Ave S            30
# Aske St                    30
# Mount Carmel Pl            30
# Grandview Pl               30
# Stryker St                 30
# 45th Dr                    30
# 128th St                   30
# E 191st St                 30
# Mac Donough St             30
# Park Terrace West          30
# Hollis Court Blvd          30
# 190th St                   29
# Knolls Cres                29
# Clarke Pl                  29
# Mosholu Pky                29
# Mosely Ave                 29
# Buchanan Pl                29
# E 114th St                 29
# Nameoke St                 29
# Seddon St                  29
# E 185th St                 29
# Tudor Pl                   29
# E 113th St                 29
# Clintonville St            29
# Parkview Ave               28
# Antin Pl                   28
# 116th Ave                  28
# Hill St                    28
# Bronx Park                 28
# St Andrews Pl              28
# Ellwood St                 28
# 159th Rd                   28
# Parkville Ave              28
# Schenck St                 28
# 163rd Ave                  28
# Hinckley Pl                28
# Union Trnpike              28
# 87th Dr                    28
# Amory Ct                   28
# St Georges Cres            28
# 76th Dr                    28
# McDonough Ave              28
# Osborn St                  28
# Pelton Ave                 28
# Arden St                   27
# Bay 13th St                27
# W 219th St                 27
# Asch Loop                  27
# Central Park West.         27
# Borough Pl                 27
# 21st Rd                    27
# Leggett Ave                27
# Quarry Rd                  27
# Beach 96th St              27
# Nurge Ave                  27
# Broadway Aly               27
# Hoyt Ave North             27
# Geranium Ave               27
# Walnut Ave                 27
# 42nd Rd                    27
# Osborne Pl                 27
# Belvidere St               27
# Banner Ave                 27
# Highland Pl                27
# Brighton Ct                27
# Philip Ave                 27
# Plaza Street West          27
# Allendale St               26
# Beach 79th St              26
# Scott Pl                   26
# Glover St                  26
# Beach 9th St               26
# S 11th St                  26
# 223rd St                   26
# Tilden St                  26
# Stebbins Ave               26
# Macy Pl                    26
# W 191st St                 26
# Peters Pl                  26
# Amboy Rd                   26
# Brown Pl                   26
# Beach 58th St              26
# Merriam Ave                26
# Beach 56th St              26
# Beach 43rd St              26
# Powers Ave                 26
# Dill Pl                    26
# St Marys St                26
# Erskine Pl                 26
# Beach 13th St              26
# Sea Breeze Ave             26
# Arlington Terrace          25
# Garfield St                25
# Mohegan Ave                25
# Britton St                 25
# Hollis Ave                 25
# Forrest St                 25
# Grote St                   25
# E 209th St                 25
# Coster St                  25
# W 178th St                 25
# Ardsley Loop               25
# W 156th St                 25
# Tehama St                  25
# Thayer St                  25
# E 203rd St                 25
# E 133rd St                 25
# Erasmus St                 25
# Frame Pl                   25
# Quimby Ave                 25
# St Josephs Ave             25
# Echo Pl                    25
# Barton Ave                 25
# 19th Rd                    25
# Manse St                   25
# Coyle St                   25
# Anderson Ave               25
# Columbus Cir               25
# Cambridge Ave              25
# Coleman Sq                 25
# Beach 84th St              25
# Ridgewood Ave              24
# Gates Pl                   24
# Christopher Ave            24
# Garfield Ave               24
# Brower Ct                  24
# Reservoir Oval East        24
# Pople Ave                  24
# Louisa St                  24
# 53rd Pl                    24
# 225th St                   24
# Van Sinderen Ave           24
# 56th Dr                    24
# Montauk St                 24
# Kalmia Ave                 24
# Central  Park North        24
# Union Square East          24
# W Brighton Ave             24
# Knapp St                   24
# Union Square West          24
# Delmonico Pl               24
# Wright St                  24
# Kneeland Ave               23
# Avon St                    23
# Anchorage Pl               23
# E 123rd St                 23
# Whitney Pl                 23
# Terrace Pl                 23
# Langham St                 23
# Canarsie Rd                23
# Victor St                  23
# Macnish St                 23
# Taras Shevchenko Pl        23
# Bay 40th St                23
# Grattan St                 23
# E 239th St                 23
# Madison Avenue Brg         23
# Bay 50th St                22
# Murdock Ct                 22
# Soundview Ave              22
# Van Duzer St               22
# Lott Ave                   22
# Chisholm St                22
# Georgia Rd                 22
# Polhemus Pl                22
# St James Ave               22
# Lamport Pl                 22
# Quay St                    22
# 25th Rd                    22
# Dana Ct                    22
# 82nd Dr                    22
# E 235th St                 22
# Brevoort St                22
# Quince Ave                 22
# Oak Tree Pl                22
# PARK LN SO.                22
# Beekman Ave                22
# Palisade Ave               22
# W 188th St                 22
# Humphreys St               22
# Brighton 1st Rd            21
# Furman Ave                 21
# Sound St                   21
# Loubet St                  21
# Guider Ave                 21
# Waterbury Ave              21
# W Mount Eden Ave           21
# W 227th St                 21
# W 197th St                 21
# Van Doren St               21
# E 155th St                 21
# Cannon Pl                  21
# 158th St                   21
# W 228th St                 21
# Terrace View Ave           21
# Mosholu Ave                21
# Beach 29th St              21
# Park Ln                    21
# Poplar Ave                 21
# Greenwood Ave              21
# Nansen St                  21
# Bronx Park Ave             21
# Stone St                   21
# 83rd Dr                    21
# Woods Pl                   21
# Sampson Ave                21
# Hudson Ave                 21
# Middagh St                 21
# Atlantic Commons           21
# Sackman St                 21
# Thatford Ave               21
# Beach 59th St              21
# Village Rd                 21
# 20th Ln                    21
# Rockaway Beach Dr          21
# 88th Rd                    21
# Beach 109th St             21
# Ash St                     21
# Commerce St                21
# Brooklyn Avenue            20
# Deerfield Rd               20
# Heyson Rd                  20
# Marginal St West           20
# Tompkins Pl                20
# Hancock Pl                 20
# Popham Ave                 20
# Claremont Pky              20
# Dey St                     20
# Sidney Pl                  20
# St Edwards St              20
# Beach 105th St             20
# Matilda Ave                20
# Nereid Ave                 20
# Father Zeiser Pl           20
# Austin Pl                  20
# Brevoort Pl                20
# Dorsey St                  20
# Lyman Pl                   20
# 187th Pl                   20
# St Pauls Pl                20
# 104th Ave                  20
# Aldus St                   20
# 182nd Pl                   20
# Bay 41st St                20
# Schroeders Ave             20
# Hyatt St                   20
# Park Terrace East          20
# Harway Ave                 20
# Bogardus Pl                20
# Davis Ave                  20
# Kensington St              20
# Samuel Dickstein Plz       19
# Hermany Ave                19
# Hempstead Ave              19
# W 259th St                 19
# 24th Rd                    19
# 22nd Dr                    19
# Old New Utrecht Rd         19
# Beach 40th St              19
# 71st Dr                    19
# Crotona Pl                 19
# Bartow Ave                 19
# 22nd Rd                    19
# Pearsall Ave               19
# Gravett Rd                 19
# Saxon Ave                  19
# Willow St                  19
# Plaza St                   19
# Carroll Pl                 19
# 232nd St                   19
# Claver Pl                  19
# Vietor Ave                 19
# Corson Ave                 19
# Haspel St                  19
# Reeves Ave                 19
# Hart Pl                    19
# Bolton St                  19
# Truxton St                 19
# Rosewood St                19
# Burns St                   18
# 53rd Rd                    18
# Sanders Pl                 18
# Kathleen Ct                18
# 27th Rd                    18
# 59th Pl                    18
# Albert Rd                  18
# Curtis St                  18
# Fort George Ave            18
# Marathon Pky               18
# 146th Ter                  18
# Lawton St                  18
# West Farms RD              18
# Far Rockaway Blvd          18
# E 202nd St                 18
# Lenox Terrace Pl           18
# Fairmount Pl               18
# Weehawken St               18
# Falmouth St                18
# Verona Pl                  18
# Cranford Ave               18
# Porter Ave                 18
# Noll St                    18
# Provost St                 18
# Debevoise Ave              18
# Carter Ave                 18
# Ryawa Ave                  18
# Mac Kay Pl                 18
# Seabury Pl                 18
# W Farms Rd                 18
# Ogden Ave                  17
# Central Park North         17
# Jefferson Pl               17
# Baker Ave                  17
# Duncan St                  17
# Plainview Ave              17
# Merrill St                 17
# Martin Luther King P       17
# Pitman Ave                 17
# Willow Ln                  17
# Worthen St                 17
# 94th Ave                   17
# Varick Ave                 17
# Market Slip                17
# 141st Pl                   17
# 78th Dr                    17
# 55th Rd                    17
# Rowland St                 17
# Bay 8th St                 17
# Irwin St                   17
# Croton Loop                17
# Delmar Loop                17
# Ryder St                   17
# Willmohr St                17
# Van Brunt St               17
# 64th Ln                    17
# Sloan Pl                   17
# Hunters Point Ave          17
# W 79st Transverse Rd       17
# Central Park South.        17
# Dooley St                  17
# Inwood St                  17
# 58th Pl                    17
# W 220th St                 17
# Union Pl                   17
# Rapelye St                 16
# Clara St                   16
# Suburban Pl                16
# Murray Ln                  16
# Watkins St                 16
# Beach 80th St              16
# Buckingham Rd              16
# Sherman St                 16
# W Thames St                16
# De Reimer Ave              16
# 111th Ave                  16
# Ridgewood Pl               16
# Poyer St                   16
# Thornton Pl                16
# Sumner Pl                  16
# Celtic Ave                 16
# Cedarcroft Rd              16
# Lowerre Pl                 16
# North End Ave              16
# Cobek Ct                   16
# Melville St                16
# Hoffman Dr                 16
# Blackstone Ave             16
# Seminole Ave               16
# Tennis Ct                  16
# ...
# 15 4     2300
# 24 4     2287
# 19 4     2254
# 43 4     2230
# 28 4     2209
# I 31     2208
# 95       2204
# 08 2     2191
# 12 4     2181
# 16 3     2177
# 10 3     2139
# 50       2133
# 18 4     2131
# 05 6     2104
# 04 6     2100
# 53       2091
# 35 3     2057
# 60       2048
# X        2042
# 05 4     2005
# J 32     1995
# 18 3     1995
# S 32     1990
# 11 4     1975
# 20 4     1925
# C1       1902
# 41 4     1897
# 48       1880
# 04 3     1859
# R 32     1839
# 61 7     1830
# 14 6     1827
# 59 3     1817
# 41 3     1815
# 32 4     1805
# 52       1803
# 57       1783
# 55 3     1781
# B 77     1769
# P        1759
# 37 4     1741
# J 42     1741
# 07 6     1708
# 34 4     1704
# 27 4     1703
# 02 6     1699
# 10 4     1681
# A 17     1671
# 35 4     1649
# 95 1     1647
# 51-P     1644
# 47       1642
# A 41     1640
# 42 4     1633
# 24 3     1619
# 06 2     1611
# 29 4     1608
# 58       1608
# MC 9     1607
# 05 7     1587
# 01-A     1566
# A 42     1558
# C1 3     1547
# 54       1523
# 26 4     1521
# 58 7     1511
# 28 3     1510
# 21 4     1497
# 32 3     1494
# C 31     1463
# 18 2     1461
# 34 3     1460
# 11 6     1457
# 10 6     1427
# 36 4     1405
# 08 6     1399
# CC4      1385
# CC7      1365
# 46 3     1357
# CCA      1351
# 22 7     1350
# C 17     1344
# 31 4     1335
# E 42     1332
# 17 6     1328
# D 77     1320
# G 42     1304
# 07 7     1302
# 002      1292
# 56 7     1286
# 59 7     1273
# M 31     1272
# C 42     1268
# 16 7     1268
# 19 7     1267
# 12 2     1262
# 06 6     1255
# CCB      1242
# 09 6     1240
# 16 6     1234
# 004      1233
# K 42     1233
# C-PM     1233
# D 41     1228
# 09 2     1226
# 43 3     1224
# S 31     1222
# 014      1218
# A 21     1217
# 60 7     1211
# T 31     1207
# 12 7     1200
# 10 7     1198
# O 31     1189
# 23 4     1182
# 18 6     1180
# 49 3     1178
# 02 7     1172
# 20 7     1168
# 20 3     1167
# 03 7     1158
# 05 2     1155
# 02 2     1150
# 52-P     1148
# 11 7     1145
# 02 4     1143
# L 32     1141
# 20 6     1140
# L 31     1139
# 21 7     1136
# G 77     1132
# 15 7     1130
# E 41     1124
# 09 4     1123
# 08 7     1121
# 23 7     1117
# 33 7     1103
# 01-P     1101
# Y        1100
# 26 2     1088
# 39 4     1087
# 14 7     1085
# 07 2     1079
# M 42     1078
# E 17     1076
# 49 7     1068
# 44 7     1066
# 21 6     1065
# 38 4     1063
# 15 6     1057
# F 77     1053
# 51 2     1049
# 04 7     1048
# 19 6     1045
# 09 7     1042
# 08 4     1035
# 48 7     1034
# J 31     1033
# G 17     1033
# F 41     1032
# I 77     1031
# C 41     1030
# 54 7     1023
# 042      1020
# E 77     1020
# G 41     1006
# 005       995
# 24 7      995
# 30 2      992
# 01A       991
# 17 2      985
# 040       983
# 039       979
# D 21      964
# 14 4      964
# 064       962
# 42 7      961
# 003       960
# 12 6      959
# B 21      957
# 031       957
# 44 4      954
# 34 2      950
# 043       950
# 04-P      945
# U 32      945
# 047       938
# H 42      935
# 18 7      931
# 22 6      929
# 74 1      927
# 26 7      927
# K 21      922
# 010       916
# 46 7      908
# 07 3      907
# 038       899
# 25 7      899
# 016       897
# 046       896
# Q 31      894
# J 41      894
# 11-A      886
# 069       884
# 22 4      883
# 019       883
# 027       880
# 22 2      879
# A 22      877
# H 41      875
# 061       874
# 43 7      873
# F 21      870
# 31 3      870
# 16 4      869
# CC6       865
# V 42      864
# 03-P      863
# T 41      849
# 51 7      847
# W 42      846
# 45 7      844
# K 41      842
# A-PM      842
# 27 3      839
# 12 3      839
# 070       839
# 66        829
# D 22      824
# 051       821
# 077       814
# B 17      814
# 076       809
# 075       808
# 06-P      805
# 007       803
# 47 7      802
# 028       799
# 70 1      786
# 04 4      785
# C 22      783
# 048       783
# 072       782
# 045       781
# L 77      779
# 06 7      779
# 052       777
# 30 6      774
# 77 1      770
# 03-A      768
# 55 7      765
# 049       764
# 25-A      758
# 63 1      749
# 073       746
# O 99      744
# 10 2      744
# H 77      740
# 39 7      739
# D 17      738
# X 41      733
# 37 7      731
# 066       730
# P 41      729
# L 41      727
# 19 2      724
# 50 7      724
# I 21      723
# CC5       719
# 006       718
# 58 3      717
# 31 2      714
# B2        711
# 40 4      711
# V 41      710
# J 21      709
# 53 7      709
# 054       706
# 63        705
# 60 3      703
# 055       703
# 044       699
# 24 6      695
# 25 6      692
# 020       688
# 54 1      687
# 058       684
# 23 6      683
# K 31      681
# U 31      679
# 008       678
# O 77      675
# 31 7      674
# 75 1      671
# 27 2      668
# R 41      663
# 59 1      659
# 04-A      658
# 068       658
# 057       655
# 62        648
# N 77      648
# 06 4      647
# 28-A      647
# 26-A      646
# T 32      643
# 42 2      640
# S 41      638
# O 41      636
# 28 1      635
# 059       635
# E 22      630
# 24-A      628
# F 17      628
# 34-A      625
# F 42      622
# 28 2      621
# 35 7      621
# SC1       618
# U 42      611
# 50 1      610
# N 31      610
# 62 1      609
# 065       607
# W 41      605
# 52 7      605
# 48 2      600
# 52 2      599
# 35-A      598
# 57 7      598
# G 21      596
# 46 2      596
# 34 7      593
# 50 2      592
# V 31      590
# 050       585
# T 42      583
# 65        582
# H 22      581
# 57 2      580
# 40 2      580
# 44 2      574
# Z         573
# 20 1      573
# 29-A      573
# 76 1      569
# R 42      568
# J 77      567
# G 31      566
# 55 1      559
# 210J      557
# I 42      556
# 39 2      551
# I 17      551
# L 99      548
# 024       548
# 14 2      547
# 074       546
# 062       545
# 65 1      544
# N 41      542
# 060       541
# 39 3      540
# 022       540
# 43 2      538
# 67 1      538
# 21 1      538
# 57 1      538
# 29 2      536
# F 10      533
# 40 1      532
# 27-A      531
# N 99      530
# 31-A      530
# 023       525
# 35 1      522
# 029       522
# M 41      521
# 071       520
# 53 1      519
# 66 1      516
# 30-A      516
# 22 1      514
# C 21      513
# 61 1      512
# 45 4      512
# 23-A      511
# 71 6      510
# 08 1      509
# 032       507
# 44 1      503
# 26 6      503
# G 10      502
# K 77      502
# B 41      500
# 58 1      499
# 45 2      497
# 33 2      496
# 27 6      496
# 33 4      494
# 47 2      492
# 01 9      490
# 41-A      490
# X 99      489
# 52 1      485
# 28 7      485
# 02-A      484
# 33 1      483
# H 31      481
# 22-A      481
# 056       480
# 64 6      478
# 43 6      472
# 36-A      472
# 35 2      471
# 37 2      470
# 28 6      468
# 015       467
# B 42      465
# 02-P      465
# 25 1      464
# 05-A      463
# 31 6      463
# 33 6      463
# A 32      462
# 10-A      461
# M 21      461
# 17-A      460
# 71 1      459
# 27 7      451
# 41 6      448
# 20-A      448
# I 22      447
# 42 1      443
# 36 6      442
# 41 7      441
# 017       441
# H 17      441
# J 99      441
# U 41      439
# 30 1      438
# 053       438
# 32 6      437
# 43-A      436
# B 31      435
# 03 1      434
# 02 1      434
# 61 2      433
# 01B       432
# Y 41      432
# 18 1      430
# 15 2      429
# Y 99      427
# 20 2      427
# 55 2      427
# P 31      424
# 66 6      422
# CC8       421
# N 42      421
# MC        420
# F 31      415
# F 22      415
# 19-A      415
# 18-A      413
# 21-A      410
# D 42      410
# A 62      403
# 06-A      403
# D1        402
# H 21      401
# 90 6      397
# O 42      397
# 25 3      396
# 32 7      395
# 79 1      394
# 40 7      394
# 36 7      394
# 02 8      392
# 12 1      388
# 120       388
# 74        385
# 05-P      384
# 37-A      384
# N 21      382
# 41 2      381
# 51 3      379
# 32 2      379
# 29 7      378
# M 77      377
# 42 6      376
# X 42      376
# 66 2      371
# R 99      371
# 70        370
# 78 1      367
# 24-P      366
# 25-P      366
# 34 6      366
# 80 1      365
# 43-P      363
# Q 41      362
# 101       362
# O 21      357
# 38 7      352
# 96 6      349
# 115       348
# 27-P      347
# 15-A      346
# L 21      343
# R 31      342
# 011       342
# B 62      338
# 16 1      335
# 31-P      334
# 104       333
# 41-P      327
# 69 1      327
# 62 6      327
# 47 1      326
# 07-A      325
# 29 6      325
# 26-P      325
# 84 6      324
# 77        323
# Z 41      322
# 102       316
# 021       315
# 44 6      315
# 10-P      315
# N 15      313
# SI 9      312
# 113       309
# 28-P      308
# 108       307
# 36 2      306
# C-AM      306
# D-AM      304
# 78 6      304
# 38 2      302
# 68        301
# E 21      301
# S4 9      299
# 14-A      297
# 46 1      296
# 30 7      296
# 23-P      295
# 037       293
# 10 1      291
# Q 42      289
# 041       289
# 08-P      286
# 14 1      285
# 17-P      284
# 37 6      284
# 110       283
# CC-A      281
# B 22      278
# G 22      276
# 67        276
# B2 3      274
# 44-P      273
# 30-P      273
# 32-A      271
# 106       270
# 38-A      270
# 07-P      269
# 36 3      266
# 81 6      265
# 49 1      265
# 033       265
# 75        265
# 23 1      265
# 44 3      264
# Y 32      261
# C 62      258
# 64        258
# X 31      254
# 036       253
# 48 6      251
# 16 2      250
# 22-P      250
# 16-A      250
# 54 2      249
# 42 3      249
# 34-P      249
# 18-P      246
# 20-P      246
# 46 6      245
# 38 6      242
# 76        242
# 77 6      241
# A-AM      241
# 40 6      237
# 08-A      237
# Z 21      234
# 68 6      233
# S5 9      232
# 59 2      232
# 45 6      230
# 91 6      230
# 130       230
# 45-A      229
# 29-P      229
# 12-A      226
# 37-P      225
# 116       225
# 15F       225
# S3 9      224
# 30 3      223
# D-PM      222
# C 10      218
# 26 3      218
# 93 6      217
# 51 1      216
# 15-P      215
# 53 2      213
# 117       210
# A 10      210
# D 10      209
# 01 1      208
# J-PM      207
# P 21      205
# 118       205
# 72 6      205
# 21-P      205
# 50 3      201
# 030       201
# 009       201
# 034       200
# E-PM      200
# 35 6      199
# 56 1      196
# 67 6      196
# 035       196
# 68 1      196
# 69 6      195
# E-AM      192
# 58 2      192
# 79        191
# 64 1      189
# 24 1      189
# B-PM      189
# 13A       189
# S 99      188
# L-AM      188
# Z1        187
# 10 8      185
# 78        184
# 32 1      183
# 018       178
# 114       178
# H-PM      178
# G-PM      177
# 12-P      176
# 32-P      175
# F-AM      175
# 71        171
# I 41      168
# S 21      167
# 27 1      165
# 21 2      164
# 60 1      164
# 121       163
# 87 6      163
# S 42      162
# F-PM      162
# 06 1      161
# 012       161
# 75 6      160
# 50 6      158
# 97 6      157
# 69        157
# 39 6      155
# 19-P      149
# 42-A      145
# MS 9      143
# E 10      142
# 025       141
# G-AM      141
# 04 1      140
# B 32      139
# J-AM      139
# 38-P      137
# K-PM      137
# 13        136
# 45 3      135
# L-PM      135
# 60 2      135
# 39 1      134
# 62 2      134
# 80        132
# 94 6      131
# 40-A      131
# 55 6      130
# 22 3      130
# 111       128
# 48 3      128
# 105       125
# 36 1      124
# 112       124
# 15E       123
# 47 3      120
# Z1 2      120
# H-AM      120
# P 42      118
# D 31      118
# 82 6      117
# 85 6      117
# U 99      116
# 39-A      114
# O-AM      112
# 3         112
# 74 6      111
# F 32      111
# 47 6      111
# 1         110
# L 42      108
# I-AM      108
# Q 99      106
# CU 9      104
# 46 4      103
# 4         103
# T 99      101
# 65 6      101
# Y 21      101
# T 21       99
# 76 6       98
# 09 1       98
# M 99       96
# 19 1       94
# P 99       94
# D1 3       92
# 44-A       90
# 16-P       89
# 79 6       89
# P-PM       89
# H 99       89
# O-PM       88
# 11 1       88
# 37 1       85
# 45-P       85
# K-AM       85
# V 21       84
# SC2        83
# 23 2       82
# 067        82
# N-PM       82
# 13 8       81
# 49 6       79
# M 23       77
# 119        77
# 23 3       75
# 56 2       75
# 109        74
# B 10       74
# 98 6       73
# 61 3       73
# K 99       73
# P-AM       73
# 57 6       72
# P 23       71
# 09-A       70
# 12C        70
# 026        69
# V 32       69
# 082        67
# W 21       67
# 8          67
# 73 6       66
# 58 6       66
# 15D        64
# 33-A       63
# 70 2       63
# I-PM       63
# 02 9       62
# U 21       61
# 34 1       61
# 65 2       60
# 29 3       60
# H 32       60
# 03 8       59
# Q 21       57
# 14-P       56
# 03A        55
# E 31       55
# 90 1       55
# 37 3       55
# V 99       54
# M-PM       54
# R 21       53
# N 23       53
# 54 6       52
# 05 1       52
# 63 2       52
# Z2         51
# K 62       51
# 09-P       51
# B 99       50
# Z3 2       48
# 6          48
# 17 1       48
# 11-P       48
# M-AM       48
# 099        47
# 24 2       47
# 04 8       46
# 69 2       46
# 063        46
# B-AM       45
# 95 6       45
# O 32       45
# M 32       45
# S1 9       44
# O 23       44
# 100        44
# 25 2       43
# 49 2       42
# 38 3       41
# 07 1       41
# 51 6       40
# 05 8       40
# A 99       38
# 90         37
# L 15       37
# 52 3       36
# 29 1       36
# 70 6       35
# 02A        35
# D 62       33
# D 32       32
# 15 1       32
# N-AM       32
# Z2 2       32
# CC-P       31
# 47-P       31
# 13 4       31
# 11A        29
# 60 6       29
# 107        29
# Q 23       28
# H 10       27
# 26 1       27
# 41 1       27
# 1S 3       27
# 68 2       26
# 31 1       26
# 12A        26
# 2          25
# 080        25
# 083        25
# 097        25
# 47-A       24
# 087        23
# 081        23
# 9          23
# 82         23
# 08 8       23
# 2B         22
# K 32       22
# 103        22
# 56 6       22
# 59 6       21
# 4B 3       20
# Z3         20
# 096        20
# G 99       19
# 46-A       19
# 92 6       19
# 46-P       18
# P 32       18
# 63 6       18
# D 99       18
# 91 1       18
# 52 6       18
# X 32       17
# 07 8       17
# 140        17
# 12B        17
# X 21       17
# C2 3       17
# 33-P       17
# 88         16
# 5          16
# 94 1       16
# 80 6       16
# I 32       16
# C 99       16
# F 99       15
# 43 1       15
# 88 6       15
# Q 32       15
# 15A        14
# SC3        14
# 82 1       14
# 09 8       14
# 83 6       14
# 94         14
# 088        14
# 089        13
# 61 6       13
# 53 6       13
# 45 1       13
# 302J       13
# 64 2       12
# 1B         12
# CU         12
# 200        12
# 2B 3       12
# 190        12
# 7          12
# 40-P       11
# 15B        11
# E 99       11
# 88 1       11
# 06 8       11
# 092        11
# 15 8       11
# T 23       11
# 1B 3       10
# C2         10
# 86 6       10
# BK         10
# 53-A       10
# 72         10
# 98          9
# 58-A        9
# 38 1        9
# 54-P        9
# A2          9
# K 15        9
# 85          8
# 60-A        8
# 14A         8
# 150         8
# I 99        8
# M 15        8
# 67 2        8
# S8          8
# 123         7
# 15C         7
# 078         7
# 89 8        7
# 012A        7
# MN          7
# P 15        7
# 57-P        7
# 084         6
# S5          6
# E 62        6
# 73          6
# BX 9        6
# R 15        6
# MS          6
# 48 1        6
# 1S          6
# BK1         5
# 11 8        5
# 196         5
# 72 1        5
# 185         5
# BK 9        5
# 180         5
# 133         4
# 160         4
# S 23        4
# U 23        4
# 2S          4
# S9 9        4
# 134         4
# 87 1        4
# F 62        4
# 176         4
# 126         4
# 85 1        3
# S1          3
# 92 1        3
# 84          3
# 193         3
# 55-P        3
# 54 3        3
# 166         3
# 39-P        3
# 151         3
# 199         3
# 129         3
# 079         3
# 03 9        2
# 73 1        2
# T 15        2
# 182         2
# 93 1        2
# G 62        2
# 13 6        2
# R 23        2
# 127         2
# 142         2
# 168         2
# 095         2
# 53 3        2
# 95W         2
# 4B          2
# 145         1
# 61-P        1
# 55-A        1
# A2 3        1
# S12         1
# 094         1
# MN 9        1
# 14B         1
# 165         1
# S6 9        1
# 131         1
# 04 9        1
# 87          1
# Name: Violation Post Code, dtype: int64
# 21-No Parking (street clean)      368898
# 38-Failure to Display Muni Rec    310847
# 37-Expired Muni Meter             174173
# 14-No Standing                     87427
# 20A-No Parking (Non-COM)           74167
# 69-Failure to Disp Muni Recpt      54538
# 31-No Stand (Com. Mtr. Zone)       43363
# 47-Double PKG-Midtown              31287
# 16A-No Std (Com Veh) Non-COM       22359
# 16-No Std (Com Veh) Com Plate      19600
# 42-Exp. Muni-Mtr (Com. Mtr. Z)     19371
# 24-No Parking (exc auth veh)       14831
# 20-No Parking (Com Plate)          14181
# 78-Nighttime PKG on Res Street      7908
# 17-No Stand (exc auth veh)          7878
# 18-No Stand (bus lane)              2270
# 23-No Parking (taxi stand)          1349
# 89-No Stand Exc Com Plate           1040
# 35-Selling/Offer Merchandise         798
# 39-Overtime PKG-Time Limt Post       677
# 13-No Stand (taxi stand)             604
# 19-No Stand (bus stop)               385
# 26-No Stnd (for-hire veh only)       347
# 04A-Downtown Bus Area, Non-Bus       292
# 47A-Angle PKG - Midtown              283
# 35-Selling /Offer Merchandise        141
# 10-No Stopping                       118
# 43-Exp. Mtr. (Com. Mtr. Zone)        102
# 32-Overtime PKG-Missing Meter         11
# 04B-Downtown Bus Area, No Prmt        11
# 46B-Double Parking (Com-100Ft)         8
# 71A-Insp Sticker Expired (NYS)         4
# 48-Bike Lane                           4
# 46A-Double Parking (Non-COM)           4
# 33-Feeding Meter                       4
# 40-Fire Hydrant                        3
# 25-No Stand (commutr van stop)         3
# 70A-Reg. Sticker Expired (NYS)         3
# 44-Exc Limit (Com. Mtr. Zone)          2
# 04-Downtown Bus Area, 3 Hr Lim         2
# 32A Overtime PKG-Broken Meter          1
# 68-Not Pkg. Comp. w Psted Sign         1
# Name: Violation Description, dtype: int64

# %%
spark = pyspark.sql.SparkSession.builder.config("spark.executor.memory", "16g").config("spark.driver.memory", "16g").getOrCreate() #init pyspark

# %%
dfs = spark.read.csv('/content/drive/MyDrive/datasets/parking2017.csv', sep=',', inferSchema=True, header=True, multiLine=True) #read the csv by spark

# %%
dfs.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Summons Number: long (nullable = true)
#  |-- Plate ID: string (nullable = true)
#  |-- Registration State: string (nullable = true)
#  |-- Plate Type: string (nullable = true)
#  |-- Issue Date: string (nullable = true)
#  |-- Violation Code: integer (nullable = true)
#  |-- Vehicle Body Type: string (nullable = true)
#  |-- Vehicle Make: string (nullable = true)
#  |-- Issuing Agency: string (nullable = true)
#  |-- Street Code1: integer (nullable = true)
#  |-- Street Code2: integer (nullable = true)
#  |-- Street Code3: integer (nullable = true)
#  |-- Vehicle Expiration Date: integer (nullable = true)
#  |-- Violation Location: integer (nullable = true)
#  |-- Violation Precinct: integer (nullable = true)
#  |-- Issuer Precinct: integer (nullable = true)
#  |-- Issuer Code: integer (nullable = true)
#  |-- Issuer Command: string (nullable = true)
#  |-- Issuer Squad: string (nullable = true)
#  |-- Violation Time: string (nullable = true)
#  |-- Violation County: string (nullable = true)
#  |-- Violation In Front Of Or Opposite: string (nullable = true)
#  |-- House Number: string (nullable = true)
#  |-- Street Name: string (nullable = true)
#  |-- Date First Observed: integer (nullable = true)
#  |-- Law Section: integer (nullable = true)
#  |-- Sub Division: string (nullable = true)
#  |-- Days Parking In Effect    : string (nullable = true)
#  |-- From Hours In Effect: string (nullable = true)
#  |-- To Hours In Effect: string (nullable = true)
#  |-- Vehicle Color: string (nullable = true)
#  |-- Vehicle Year: integer (nullable = true)
#  |-- Feet From Curb: integer (nullable = true)
#  |-- Violation Post Code: string (nullable = true)
#  |-- Violation Description: string (nullable = true)

# %%
#dropping the index column and dropping the columns that contained a single value
drop_cols = ['_c0','Issuing Agency', 'Law Section', 'Days Parking In Effect    ', 'Feet From Curb']

dfs = dfs.drop(*drop_cols)

# %%
renameing =(col.replace(' ', '_') for col in dfs.columns) #rename the column to remove the space
dfs = dfs.toDF(*renameing)

# %%
#remaping the colors by shortcut
dfs = dfs.replace({'WHITE': 'WH', 'BLACK':'BK', 'GREY':'GY', 'BLUE':'BL', 'RED':'RD','BROWN':'BR','GREEN':'GR', 'GOLD':'GL','YELLO':'YW', 'TAN':'TN', 'ORANG':'OR', 'PURPL':'PR'},subset=['Vehicle_Color'])

# %%
#limit the year from 1950 to 2018
dfs = dfs.filter("Vehicle_Year > 1950 and Vehicle_Year <= 2018 ")

# %%
Vehicle_Make_del = dfs.groupby('Vehicle_Make').count().orderBy('count', ascending=True).filter("count < 100") #value count for Vehicle_Make

# %%
Vehicle_Make_del = Vehicle_Make_del.select(Vehicle_Make_del.Vehicle_Make).rdd.flatMap(lambda x: x).collect() #convert to list of values

# %%
dfs = dfs.filter(~(dfs.Vehicle_Make).isin(Vehicle_Make_del))  #dropped the values with less than 100 examples

# %%
dfs = dfs.filter(~(dfs.Violation_In_Front_Of_Or_Opposite).isin(['I','R'])) #I and R values with not enough examples so we dropped the I and R

# %%
Vehicle_Body_Type_del = dfs.groupby('Vehicle_Body_Type').count().orderBy('count', ascending=True).filter("count < 100")  #value count for Vehicle_Body_Type

# %%
Vehicle_Body_Type_del = Vehicle_Body_Type_del.select(Vehicle_Body_Type_del.Vehicle_Body_Type).rdd.flatMap(lambda x: x).collect() #convert to list of values

# %%
dfs = dfs.filter(~(dfs.Vehicle_Body_Type).isin(Vehicle_Body_Type_del)) #dropped the values with less than 100 examples

# %%
dfs = dfs.withColumn('Vehicle_Expiration_year', col('Vehicle_Expiration_Date').substr(0, 4)) #convert Vehicle_Expiration_Date to year
dfs = dfs.drop('Vehicle_Expiration_Date')

# %%
dfs.show()
# Out:
# +--------------+--------+------------------+----------+----------+--------------+-----------------+------------+------------+------------+------------+------------------+------------------+---------------+-----------+--------------+------------+--------------+----------------+---------------------------------+------------+------------+-------------------+------------+--------------------+------------------+-------------+------------+-------------------+---------------------+-----------------------+
# |Summons_Number|Plate_ID|Registration_State|Plate_Type|Issue_Date|Violation_Code|Vehicle_Body_Type|Vehicle_Make|Street_Code1|Street_Code2|Street_Code3|Violation_Location|Violation_Precinct|Issuer_Precinct|Issuer_Code|Issuer_Command|Issuer_Squad|Violation_Time|Violation_County|Violation_In_Front_Of_Or_Opposite|House_Number| Street_Name|Date_First_Observed|Sub_Division|From_Hours_In_Effect|To_Hours_In_Effect|Vehicle_Color|Vehicle_Year|Violation_Post_Code|Violation_Description|Vehicle_Expiration_year|
# +--------------+--------+------------------+----------+----------+--------------+-----------------+------------+------------+------------+------------+------------------+------------------+---------------+-----------+--------------+------------+--------------+----------------+---------------------------------+------------+------------+-------------------+------------+--------------------+------------------+-------------+------------+-------------------+---------------------+-----------------------+
# |    8008528497| ESD4864|                NY|       PAS|07/26/2016|            38|             2DSD|       ME/BE|       44890|       16850|       32580|                 1|                 1|              1|     363484|          T105|           D|         0100P|              NY|                                O|         140|  W Broadway|                  0|          h1|               0800A|             0700P|           BK|        2007|                077| 38-Failure to Dis...|                   2017|
# |    8251506130|T687616C|                NY|       OMT|08/08/2016|            38|             4DSD|       TOYOT|       44890|       16850|       32580|                 1|                 1|              1|     355208|          T105|           D|         0101P|              NY|                                O|         138|  W Broadway|                  0|          h1|               0800A|             0700P|           BK|        2016|                042| 38-Failure to Dis...|                   2017|
# |    8506271319|   ZGMTK|                NY|       SRF|05/31/2017|            38|             SUBN|         GMC|       44890|       27050|       32940|                 1|                 1|              1|     363137|          T105|           E|         0101P|              NY|                                F|          66|  W Broadway|                  0|          h1|               0800A|             0700P|           BK|        2015|                051| 38-Failure to Dis...|                   2017|
# |    8506067078| FMJ6448|                NY|       PAS|04/08/2017|            38|             SUBN|       VOLKS|       16850|       15350|       44890|                 1|                 1|              1|     364011|          T105|           D|         0102P|              NY|                                F|         150|    Duane St|                  0|          h1|               0900A|             0700P|           BK|        2011|                031| 38-Failure to Dis...|                   2017|
# |    8506251333| GME8649|                NY|       PAS|01/13/2017|            38|             PICK|       DODGE|       15350|       45290|       32900|                 1|                 1|              1|     363137|          T105|           E|         0102P|              NY|                                F|         289|   Church St|                  0|          h1|               0800A|             0700P|           GY|        2016|                064| 38-Failure to Dis...|                   2018|
# |    8471210502| 18164JW|                NY|       COM|10/06/2016|            24|              VAN|       CHEVR|       28490|       15545|       22410|                 1|                 1|              1|     361841|          T105|           D|         0103P|              NY|                                O|          93|    Pearl St|                  0|          d5|               0600A|             0700P|           WH|        2005|                065| 24-No Parking (ex...|                   2017|
# |    8506257876| 54910JA|                NY|       COM|02/17/2017|            69|              VAN|        FORD|       27100|       13015|       29295|                 1|                 1|              1|     363137|          T105|           E|         0103P|              NY|                                F|         145|   Nassau St|                  0|          h1|               0700A|             0700P|           WH|        2014|                073| 69-Failure to Dis...|                   2018|
# |    8505909380| 69703MD|                NY|       COM|02/16/2017|            16|              VAN|        FORD|       21790|       23890|       22490|                 1|                 1|              1|     363518|          T105|           D|         0103P|              NY|                                F|         349|Greenwich St|                  0|          k2|               0700A|             0700P|           WH|        2014|                064| 16-No Std (Com Ve...|                   2017|
# |    8443503117| DAG2159|                NY|       PAS|08/06/2016|             4|             SUBN|       CHEVR|       11115|       32700|       12520|                 1|                 1|              1|     357086|          T105|           E|         0104P|              NY|                                F|         140|     West St|                  0|          L6|               0700A|             0700P|          BL/|        2001|                040| 04A-Downtown Bus ...|                   2017|
# |    8505054866| GDR2960|                NY|       PAS|02/04/2017|            38|             SUBN|       HONDA|       44890|       29390|       16850|                 1|                 1|              1|     364007|          T105|           C|         0107P|              NY|                                O|         115|  W Broadway|                  0|          h1|               0800A|             0700P|           BL|        2013|                043| 38-Failure to Dis...|                   2018|
# |    8504802024| 58525MG|                NY|       COM|01/16/2017|            38|              VAN|        FORD|       22410|       28490|       27410|                 1|                 1|              1|     363571|          T105|           D|         0108P|              NY|                                F|          10|  Hanover Sq|                  0|          h1|               0830A|             1000P|           WH|        2015|                072| 38-Failure to Dis...|                   2018|
# |    7809509810| GXN7810|                NY|       PAS|12/17/2016|            31|             SUBN|       DODGE|       27100|       24050|       21230|                 1|                 1|              1|     347684|          T105|           J|         0108P|              NY|                                O|          82|   Nassau St|                  0|          l3|               0700A|             0700P|           BL|        2007|                016| 31-No Stand (Com....|                   2017|
# |    8505367406| HGK3904|                NY|       PAS|05/06/2017|            31|             4DSD|       HONDA|           0|           0|           0|                 1|                 1|              1|     351250|          T105|           C|         0108P|              NY|                                F|          93|   Nassau St|                  0|          l3|               0700A|             0700P|           WH|        2013|                025| 31-No Stand (Com....|                   2018|
# |    7034747830| GZL1392|                NY|       PAS|11/01/2016|            16|             4DSD|         BMW|       20890|       10510|       44890|                 1|                 1|              1|     351949|          T105|           C|         0110P|              NY|                                F|         104| Franklin St|                  0|          k2|               0700A|             0700P|           GY|        2009|                051| 16A-No Std (Com V...|                   2017|
# |    8245055049| HFP5467|                NY|       PAS|06/28/2016|            38|             SUBN|       DODGE|       23190|       20890|       27290|                 1|                 1|              1|     351929|          T105|           N|         0110P|              NY|                                F|         110|   Hudson St|                  0|          h1|               0900A|             0700P|           RD|        2006|               X 99| 38-Failure to Dis...|                   2018|
# |    8282033005| 79825MD|                NY|       COM|10/22/2016|            38|              VAN|        FORD|       21690|       25990|       13610|                 1|                 1|              1|     361901|          Manh|           E|         0112P|              NY|                                F|         107|    Grand St|                  0|          h1|               0800A|             1000P|           WH|        2013|                038| 38-Failure to Dis...|                   2017|
# |    8505069821| HPU6178|                NY|       PAS|05/06/2017|            38|             4DSD|       HYUND|           0|           0|           0|                 1|                 1|              1|     364007|          T105|           C|         0112P|              NY|                                F|         125|   Maiden Ln|                  0|          h1|               1000A|             1000P|           BK|        2005|                052| 38-Failure to Dis...|                   2019|
# |    7079374777| HDW3526|                NY|       PAS|11/30/2016|            20|             4DSD|       TOYOT|       29290|       44890|       32590|                 1|                 1|              1|     362606|          T105|           N|         0113P|              NY|                                F|         154|   Prince St|                  0|           d|               0800A|             0600P|           WH|        2011|               X 99| 20A-No Parking (N...|                   2018|
# |    8505461800| HJJ9447|                NY|       PAS|04/10/2017|            38|             4DSD|       HONDA|       21090|       32910|       28870|                 1|                 1|              1|     355208|          T105|           D|         0113P|              NY|                                O|         129|    Front St|                  0|          h1|               0900A|             0700P|           WH|        2016|                065| 38-Failure to Dis...|                   2018|
# |    8248048536| FPY9176|                NY|       PAS|11/25/2016|            38|             SUBN|       ACURA|       10510|       32660|       14910|                 1|                 1|              1|     364898|          T105|           D|         0114P|              NY|                                O|         192|     6th Ave|                  0|          h1|               0730A|             0700P|           GY|        2008|                069| 38-Failure to Dis...|                   2017|
# +--------------+--------+------------------+----------+----------+--------------+-----------------+------------+------------+------------+------------+------------------+------------------+---------------+-----------+--------------+------------+--------------+----------------+---------------------------------+------------+------------+-------------------+------------+--------------------+------------------+-------------+------------+-------------------+---------------------+-----------------------+
# only showing top 20 rows

# %%
print('Dataframe shape:', (dfs.count(), len(dfs.columns)))
# Out:
# Dataframe shape: (822802, 31)

# %%
dfP = dfs.toPandas()

# %%
dfP.to_csv('afterCleaning.csv')
